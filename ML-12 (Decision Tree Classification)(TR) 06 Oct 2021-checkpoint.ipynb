# %% [markdown]
# ## Decision Tree - Classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("penguins_size.csv") #tree base modeller scale istemez
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
10/344
# Out:
# 0.029069767441860465

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
df["sex"].unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
df["island"].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df[df["sex"]== "."]
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
df[df.species =="Gentoo"].groupby("sex").describe().T
# Out:
# sex                           .       FEMALE         MALE
# culmen_length_mm  count     1.0    58.000000    61.000000
#                   mean     44.5    45.563793    49.473770
#                   std       NaN     2.051247     2.720594
#                   min      44.5    40.900000    44.400000
#                   25%      44.5    43.850000    48.100000
#                   50%      44.5    45.500000    49.500000
#                   75%      44.5    46.875000    50.500000
#                   max      44.5    50.500000    59.600000
# culmen_depth_mm   count     1.0    58.000000    61.000000
#                   mean     15.7    14.237931    15.718033
#                   std       NaN     0.540249     0.741060
#                   min      15.7    13.100000    14.100000
#                   25%      15.7    13.800000    15.200000
#                   50%      15.7    14.250000    15.700000
#                   75%      15.7    14.600000    16.100000
# ...

# %%
df.loc[336, "sex"] = "MALE"

# %%
df.loc[336, "sex"]
# Out:
# 'MALE'

# %% [markdown]
# ## Visualization

# %%
df["species"].value_counts()
# Out:
# Adelie       146
# Gentoo       120
# Chinstrap     68
# Name: species, dtype: int64

# %%
sns.countplot(x="species", data = df);

# %%
sns.catplot(x='species', data=df, kind='count',col='sex')

# %%
plt.figure(figsize=(12,6))
sns.pairplot(df,hue='species',palette='Dark2')

# %%
df.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
# !pip3 install plotly

# %%
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-86e89bd44552> in <module>
# ----> 1 import plotly.express as px
#
# ~\anaconda3\lib\site-packages\plotly\express\__init__.py in <module>
#      13     )
#      14
# ---> 15 from ._imshow import imshow
#      16 from ._chart_types import (  # noqa: F401
#      17     scatter,
#
# ~\anaconda3\lib\site-packages\plotly\express\_imshow.py in <module>
#       1 import plotly.graph_objs as go
#       2 from _plotly_utils.basevalidators import ColorscaleValidator
# ----> 3 from ._core import apply_default_cascade
#       4 import numpy as np
#       5
#
# ~\anaconda3\lib\site-packages\plotly\express\_core.py in <module>
#       4
#       5 from _plotly_utils.basevalidators import ColorscaleValidator
# ----> 6 from .colors import qualitative, sequential
#       7 import math
#       8 import pandas as pd
#
# ...

# %%
fig = px.scatter_3d(df, 
                    x='culmen_length_mm',
                    y='flipper_length_mm',
                    z='culmen_depth_mm',
                    color='species')
fig.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-a077d30d5b1d> in <module>
# ----> 1 fig = px.scatter_3d(df,
#       2                     x='culmen_length_mm',
#       3                     y='flipper_length_mm',
#       4                     z='culmen_depth_mm',
#       5                     color='species')
#
# NameError: name 'px' is not defined

# %%
df.select_dtypes("number")
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
# [334 rows x 4 columns]

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.select_dtypes("number").corr(),annot=True, cmap='viridis')
plt.title("Correlation Matrix")

plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
df.drop("species", axis =1)
# Out:
#         island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Torgersen              39.1             18.7              181.0
# 1    Torgersen              39.5             17.4              186.0
# 2    Torgersen              40.3             18.0              195.0
# 4    Torgersen              36.7             19.3              193.0
# 5    Torgersen              39.3             20.6              190.0
# ..         ...               ...              ...                ...
# 338     Biscoe              47.2             13.7              214.0
# 340     Biscoe              46.8             14.3              215.0
# 341     Biscoe              50.4             15.7              222.0
# 342     Biscoe              45.2             14.8              212.0
# 343     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# ...

# %%
pd.get_dummies(df.drop("species", axis =1), drop_first =True)
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_MALE
# 0               0                 1         1
# ...

# %% [markdown]
# ## Train | Test Split

# %%
X = pd.get_dummies(df.drop('species',axis=1),drop_first=True)
y = df['species']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Modelling - Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT_model = DecisionTreeClassifier(random_state=101)

# %%
DT_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=101)

# %%
y_pred = DT_model.predict(X_test)

# %% [markdown]
# ## Model Performance on Classification Tasks

# %%
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[40,  1,  0],
#        [ 2, 21,  0],
#        [ 0,  0, 37]], dtype=int64)

# %%
plot_confusion_matrix(DT_model,X_test,y_test)

# %%
from yellowbrick.classifier import ClassPredictionError

visualizer = ClassPredictionError(DT_model)

# Fit the training data to the visualizer
visualizer.fit(X_train, y_train)

# Evaluate the model on the test data
visualizer.score(X_test, y_test)

# Draw visualization
visualizer.poof();

# %%
print(confusion_matrix(y_test, y_pred)) # sadece sayıya bakarak datasetim imbalanced diyemeyiz. sonularımız bakmamız lazım
print(classification_report(y_test, y_pred)) # burada imbalanced olmadığı için, macro avg ya da weighted avg değerlerine bakılır. imbalanced veriseti için precision_micro ya bakılır
# Out:
# [[40  1  0]
#  [ 2 21  0]
#  [ 0  0 37]]
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.98      0.96        41
#    Chinstrap       0.95      0.91      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.97      0.96      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %% [markdown]
# ## Cross Validate

# %%
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer

# %%
model = DecisionTreeClassifier(max_depth=None, random_state=101)

scores = cross_validate(model, X_train, y_train, scoring = ["accuracy", "precision_macro", "recall_macro", "f1_macro"], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores
# Out:
#     fit_time  score_time  test_accuracy  test_precision_macro  \
# 1   0.006997    0.009994       0.958333              0.969697
# 2   0.005001    0.006992       0.958333              0.966667
# 3   0.005999    0.007998       0.916667              0.911111
# 4   0.004991    0.007993       0.956522              0.962963
# 5   0.005997    0.008994       1.000000              1.000000
# 6   0.005997    0.008995       1.000000              1.000000
# 7   0.006997    0.013992       1.000000              1.000000
# 8   0.015991    0.012993       1.000000              1.000000
# 9   0.006996    0.008995       0.869565              0.900000
# 10  0.007996    0.010993       1.000000              1.000000
#
#     test_recall_macro  test_f1_macro
# 1            0.933333       0.947090
# 2            0.966667       0.964912
# 3            0.929630       0.916756
# 4            0.933333       0.943355
# 5            1.000000       1.000000
# 6            1.000000       1.000000
# ...

# %%
df_scores.mean()[2:] #cv ortalamalarımızla ilkel model değerlerimiz arasında uçurum yoksa consistenti geçmişdir diyebiliriz
# Out:
# test_accuracy           0.965942
# test_precision_macro    0.971044
# test_recall_macro       0.961902
# test_f1_macro           0.963984
# dtype: float64

# %% [markdown]
# ## Feature Importances

# %%
DT_model.feature_importances_ # non parametrik bir model olduğundan scale edilmesi gerekmez, normal dağılım istemez.
# Out:
# array([0.32591819, 0.05289252, 0.54282921, 0.        , 0.07836008,
#        0.        , 0.        ])

# %%
df_f_i = pd.DataFrame(index=X.columns, data = DT_model.feature_importances_, 
                      columns = ["Feature Importance"]).sort_values("Feature Importance")
df_f_i
# Out:
#                    Feature Importance
# body_mass_g                  0.000000
# island_Torgersen             0.000000
# sex_MALE                     0.000000
# culmen_depth_mm              0.052893
# island_Dream                 0.078360
# culmen_length_mm             0.325918
# flipper_length_mm            0.542829

# %%
sns.barplot(x = df_f_i.index, y = 'Feature Importance', data = df_f_i) # root node, en fazla doğruyu tek soru ile nasıl sınıflandırabilirim...
plt.xticks(rotation = 90)
plt.tight_layout() # bir feature diğerlerine göre çok güçlüyse, overfit ile mücadele kapsamında performansımızı azaltabilir... modele bu featuru düşürerek deva edebiliriz...

# %%
X2 = X.drop(columns = ["body_mass_g"]) 
# The feature that weighs too much on the estimate can sometimes cause overfitting. For this reason, the most important feature can be dropped and the scores can be checked again

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y, test_size=0.3, random_state=101)

# %%
DT2_model = DecisionTreeClassifier(random_state=101)

# %%
DT2_model.fit(X_train2, y_train2)
# Out:
# DecisionTreeClassifier(random_state=101)

# %%
y_pred2 = DT2_model.predict(X_test2)

# %%
print(confusion_matrix(y_test2, y_pred2)) # 
print(classification_report(y_test2, y_pred2))
# Out:
# [[40  1  0]
#  [ 1 22  0]
#  [ 0  0 37]]
#               precision    recall  f1-score   support
#
#       Adelie       0.98      0.98      0.98        41
#    Chinstrap       0.96      0.96      0.96        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.98       101
#    macro avg       0.98      0.98      0.98       101
# weighted avg       0.98      0.98      0.98       101

# %%
model = DecisionTreeClassifier(random_state=101)

scores = cross_validate(model, X_train2, y_train2, scoring = ["accuracy", "precision_macro", "recall_macro", "f1_macro"], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores
# Out:
#     fit_time  score_time  test_accuracy  test_precision_macro  \
# 1   0.006996    0.011998       1.000000              1.000000
# 2   0.006980    0.007991       1.000000              1.000000
# 3   0.003997    0.010007       0.958333              0.944444
# 4   0.005992    0.008996       1.000000              1.000000
# 5   0.003998    0.005997       1.000000              1.000000
# 6   0.006999    0.009990       1.000000              1.000000
# 7   0.006994    0.004997       1.000000              1.000000
# 8   0.010999    0.018985       1.000000              1.000000
# 9   0.006997    0.006997       1.000000              1.000000
# 10  0.007993    0.015991       0.956522              0.962963
#
#     test_recall_macro  test_f1_macro
# 1            1.000000       1.000000
# 2            1.000000       1.000000
# 3            0.966667       0.952153
# 4            1.000000       1.000000
# 5            1.000000       1.000000
# 6            1.000000       1.000000
# ...

# %%
df_scores.mean()[2:]
# Out:
# test_accuracy           0.991486
# test_precision_macro    0.990741
# test_recall_macro       0.993636
# test_f1_macro           0.991667
# dtype: float64

# %%
from sklearn.metrics import make_scorer # her bir class ın öenmini ortaya koymak iiçn scoring kullanıyoruz, herbir skor için 10 cv yapıyoruz.. aşağıda. tutarlılık kontrolü ypıyoruz.

# %%
scoring = {'precision-Adelie': make_scorer(precision_score,  average='weighted', pos_label="Adelie"), # data dengesiz olsaydı avarage = micro olacaktı.
           'recall-Adelie': make_scorer(recall_score, average='weighted', pos_label ="Adelie"),
           'f1-Adelie': make_scorer(f1_score, average='weighted', pos_label = "Adelie"),
          
          'precision-Chinstrap': make_scorer(precision_score,  average='weighted', pos_label="Chinstrap"),
          'recall-Chinstrap': make_scorer(recall_score, average='weighted', pos_label ="Chinstrap"),
          'f1-Chinstrap': make_scorer(f1_score, average='weighted', pos_label = "Chinstrap"),
          
          
          'precision-Gentoo': make_scorer(precision_score,  average='weighted', pos_label="Gentoo"),
          'recall-Gentoo': make_scorer(recall_score, average='weighted', pos_label ="Gentoo"),
          'f1-Gentoo': make_scorer(f1_score, average='weighted', pos_label = "Gentoo"),
          
          }

# %%
for i, j in scoring.items():
    model = DecisionTreeClassifier(random_state=101)
    scores = cross_val_score(model, X_train2, y_train2, cv = 10, scoring = j, n_jobs = -1)
#     print([round(i, 4) for i in scores], "\n")
    print(f" {i:20} : %{scores.mean()*100:.2f}, std : %{scores.std()*100:.3f} \n") # aldığı m ilkel skorlarla cv sonuçlarım tutarlı mı kontrolü yapıyoruz.
# Out:
#  precision-Adelie     : %99.27, std : %1.470
#
#  recall-Adelie        : %99.15, std : %1.703
#
#  f1-Adelie            : %99.16, std : %1.683
#
#  precision-Chinstrap  : %99.27, std : %1.470
#
#  recall-Chinstrap     : %99.15, std : %1.703
#
#  f1-Chinstrap         : %99.16, std : %1.683
#
#  precision-Gentoo     : %99.27, std : %1.470
#
#  recall-Gentoo        : %99.15, std : %1.703
#
#  f1-Gentoo            : %99.16, std : %1.683

# %% [markdown]
# ## Visualize the Tree

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8))
plot_tree(DT_model);

# %%
plt.figure(figsize=(12,8),dpi=150)
plot_tree(DT_model, filled=True, feature_names=X.columns, class_names=df.species.unique()); # en düşük gini puanından başlayıp, en düşük gini puanına sahip olana kadar leaflere ayrıyor

# %% [markdown]
# ## Understanding Hyperparameters
#
# ### Max Depth

# %%
def report_model(model):
    model_pred = model.predict(X_test)
    model_train_pred = model.predict(X_train)
    print('\n')
    print("Test Set")
    print(confusion_matrix(y_test, model_pred))
    print('\n')
    print(classification_report(y_test,model_pred))
    print('\n')
    print("Train Set")
    print(confusion_matrix(y_train, model_train_pred))
    print('\n')
    print(classification_report(y_train,model_train_pred))
    plt.figure(figsize=(12,8),dpi=150)
    plot_tree(model,filled=True, feature_names=X.columns, class_names=df.species.unique());

# %%
pruned_tree = DecisionTreeClassifier(max_depth=3, random_state=101) # max_dept ile oynayarak overfit ve underfit değerlendirmesi yapıyoruz.. None verirsek pure değer alana kadar model çalışır
pruned_tree.fit(X_train,y_train) # max_depth ile regularizasyon yaparaız.
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=101)

# %%
report_model(pruned_tree)
# Out:
# Test Set
# [[39  2  0]
#  [ 1 22  0]
#  [ 0  0 37]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101
#
#
#
# Train Set
# [[104   1   0]
#  [  0  45   0]
#  [  1   0  82]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       0.99      0.99      0.99       105
#    Chinstrap       0.98      1.00      0.99        45
#       Gentoo       1.00      0.99      0.99        83
#
#     accuracy                           0.99       233
#    macro avg       0.99      0.99      0.99       233
# weighted avg       0.99      0.99      0.99       233

# %% [markdown]
# ## Max Leaf Nodes

# %%
pruned_tree_2 = DecisionTreeClassifier(max_leaf_nodes=5, random_state=101) #max_leaf_nodes None olursa gini değerlerime kadar çalılşır. verilen değer bölünmeyen leaf sayıusını verir. max_depth sıklıkla kullanılır.
pruned_tree_2.fit(X_train,y_train) #reule işi train setine biraz hata katarak test verilerimin iyieğitilmesini istiyorum.. gini ve entropi yakındır.. gini kullanmakta fayda avr.
# Out:
# DecisionTreeClassifier(max_leaf_nodes=5, random_state=101)

# %%
report_model(pruned_tree_2)
# Out:
# Test Set
# [[39  2  0]
#  [ 1 22  0]
#  [ 0  0 37]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101
#
#
#
# Train Set
# [[103   2   0]
#  [  0  45   0]
#  [  1   0  82]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       0.99      0.98      0.99       105
#    Chinstrap       0.96      1.00      0.98        45
#       Gentoo       1.00      0.99      0.99        83
#
#     accuracy                           0.99       233
#    macro avg       0.98      0.99      0.99       233
# weighted avg       0.99      0.99      0.99       233

# %% [markdown]
# ## Criterion

# %%
entropy_tree = DecisionTreeClassifier(criterion='entropy', random_state=101,) # entropi en yüksek np.lo2(n) değeri alır??
entropy_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=101)

# %%
report_model(entropy_tree)
# Out:
# Test Set
# [[40  1  0]
#  [ 2 21  0]
#  [ 0  0 37]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.98      0.96        41
#    Chinstrap       0.95      0.91      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.97      0.96      0.97       101
# weighted avg       0.97      0.97      0.97       101
#
#
#
# Train Set
# [[105   0   0]
#  [  0  45   0]
#  [  0   0  83]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00       105
#    Chinstrap       1.00      1.00      1.00        45
#       Gentoo       1.00      1.00      1.00        83
#
#     accuracy                           1.00       233
#    macro avg       1.00      1.00      1.00       233
# weighted avg       1.00      1.00      1.00       233

# %% [markdown]
# ## Max_features, Splitter

# %%
# splitter, hangi soruyu soracağı, best i mi yoksa random mu? max_feature ilse kaç gfeatura soru sorulacak.. 
# en fazla max_depth kullanılır.. diğerlerine fazla girmemek lazım derim....
tree = DecisionTreeClassifier(splitter = "best", max_features=3) 
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_features=3)

# %%
report_model(tree)
# Out:
# Test Set
# [[40  0  1]
#  [ 2 19  2]
#  [ 0  0 37]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.98      0.96        41
#    Chinstrap       1.00      0.83      0.90        23
#       Gentoo       0.93      1.00      0.96        37
#
#     accuracy                           0.95       101
#    macro avg       0.96      0.93      0.94       101
# weighted avg       0.95      0.95      0.95       101
#
#
#
# Train Set
# [[105   0   0]
#  [  0  45   0]
#  [  0   0  83]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00       105
#    Chinstrap       1.00      1.00      1.00        45
#       Gentoo       1.00      1.00      1.00        83
#
#     accuracy                           1.00       233
#    macro avg       1.00      1.00      1.00       233
# weighted avg       1.00      1.00      1.00       233

# %% [markdown]
# ## Find Best Parameters

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = DecisionTreeClassifier(random_state=101)

# %%
param_grid = {"splitter":["best", "random"],
              "max_features":[None, "auto", "log2", 2, 3,4, 5,6, 7], # "auto" karakök alır. yuvarlama yapar..
              "max_depth": [None, 2,3, 4, 5], # none da full olana kadar devam ederi
              "min_samples_leaf": [1, 2, 3, 4, 5, 6,7],
              "min_samples_split": [2, 3, 5, 6, 7,8,9]}

# %%
grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='f1_macro',
                          cv=10,
                          n_jobs = -1)

# %%
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=101),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 2, 3, 4, 5],
#                          'max_features': [None, 'auto', 'log2', 2, 3, 4, 5, 6,
#                                           7],
#                          'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7],
#                          'min_samples_split': [2, 3, 5, 6, 7, 8, 9],
#                          'splitter': ['best', 'random']},
#              scoring='f1_macro')

# %%
grid_model.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 5,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
y_pred = grid_model.predict(X_test)
y_train_pred = grid_model.predict(X_train)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[39  1  1]
#  [ 0 23  0]
#  [ 0  0 37]]
#               precision    recall  f1-score   support
#
#       Adelie       1.00      0.95      0.97        41
#    Chinstrap       0.96      1.00      0.98        23
#       Gentoo       0.97      1.00      0.99        37
#
#     accuracy                           0.98       101
#    macro avg       0.98      0.98      0.98       101
# weighted avg       0.98      0.98      0.98       101

# %%
print(confusion_matrix(y_train, y_train_pred))
print(classification_report(y_train, y_train_pred))
# Out:
# [[105   0   0]
#  [  0  45   0]
#  [  0   0  83]]
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00       105
#    Chinstrap       1.00      1.00      1.00        45
#       Gentoo       1.00      1.00      1.00        83
#
#     accuracy                           1.00       233
#    macro avg       1.00      1.00      1.00       233
# weighted avg       1.00      1.00      1.00       233
