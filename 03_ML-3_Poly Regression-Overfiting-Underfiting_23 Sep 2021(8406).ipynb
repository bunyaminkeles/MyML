# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# BIAS: verimizin gerçek hayata göre ne kadar hatalı, ne kadar farklı olduğunu gösterir

# %% [raw]
# hataların dağılımı.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# M=9 durumunda

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# underfitting --> future sayısını arttır. ayrıntı artsın.
#
# eğitilmemişe daha fazla data ekle.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# JOHNSON HOCA:
#
# train seti metricleri çok iyi ve test seti metricleri çok kötüyse yani aralarında uçurum varsa buna high error denir,
# train seti metricleri çok iyi ve test seti metricleri de çok iyi yani skorlar çok yakınsa buna low error denir.
#
# EMİR HOCA:
#
# Modelin başarısı, training error ların çok düşük olması değil, training ve test error ların dengede olduğu yerdir. Başarılı bir modelin bu denge alanında olması gerekir

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# polynomial regression: multi liear reg. ın özel bir çeşididir. (daha fazla eğip bükülmüş hali)
#
# nonlinear reg. de iyi çalışır.

# %% [raw]
# ML modellerinde skorların çok iyi olması datadan dataya değişir. Kimi datada 90'lı skorlar çok iyi iken, kimi datalarda 50-60 en iyi skor olabilir.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# EDWARD HOCA:
# Egimin (fonksiyonun turevi) her noktada ayni oldugu fonksiyonlar lineer fonksiyonlardir
#
# Fonksiyon x'in kendisi veya karesine eşitlenmiş ise bunlara linear deniyor. eğer X'in cosinüs veya log. gibi bir katsayısı varsa grafik daldalı biçime dönüşür, buna nonlineer denir.
#
# EMİR HOCA:
# Nonlinear regresyon, bağımlı değişken ile bir dizi bağımsız değişken arasındaki ilişkinin doğrusal olmayan bir modelini bulma yöntemidir.
# Doğrusal modellerin tahmin edilmesiyle sınırlı olan geleneksel linear regresyondan farklı olarak, nonlinear regresyon, bağımsız ve bağımlı değişkenler arasında keyfi ilişkilere sahip modelleri tahmin edebilir

# %% [markdown]
# ## Poly Regression-Overfiting-Underfiting

# %% [raw]
# THOMAS HOCA:
# Polinomsal regresyon, sınırları belli olan bir veri seti için uygun bir algoritmadır. Ancak veri setinin sınırlarının dışından gelen yeni veriler için hatası yüksek tahminlerde bulunabilir. Overfitting ve underfitting gibi konuları daha iyi anlamak için ise güzel bir algoritma deneyimi sağlar.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image.png](attachment:image.png)

# %% [raw]
# bunların derecelerini arttırdıkça datayı daha iyi tanımlama yeteneği artıyor ve bunun sonu yok. Fakat dereceyi arttırmam demek future sayısını arttırmam demek. böylece detay artıyor. aşırı arttırdığımda ise overfitting olma ihtimali oluşuyor.

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,6)

# %% [markdown]
# ## Polynomial Features

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
data = np.array([[2, 3, 4]]) 
print(data)
# Out:
# [[2 3 4]]

# %%
trans = PolynomialFeatures(degree = 2, include_bias =False) 

# PolynomialFeatures fonksiyonu ile "trans" isminde modelimizi oluşturduk. 

# include_bias = True yaparsak futurlarıma 1 sayısını ilave ediyor. 
# b0 değeri (intersect) işin içinde olduğu için zaten bias oluşuyor. ilave etmeye gerek kalmıyor.

# %% [raw]
# fit/predict ya da fit/transform fonksiyonları sayesinde kümeleme, regresyon, karar ağaçları gibi yöntemleri uygulamak, eksik değerleri doldurmak, veriyi ölçeklendirmek gibi farklı adımlarda benzer fonksiyonlar kullanmak işinizi oldukça kolaylaştırıyor.

# %%
trans.fit(data) # 2, 3, 4 , 2x3, 2x4, 3x4, 2**2, 3**2, 4**2   # bu işlemleri yapıyor.
# Out:
# PolynomialFeatures(include_bias=False)

# %%
trans.transform(data)

# fit edilmiş datamıza transform uyguluyoruz. datamızı yukardaki çarpımlar sonucunda elde edilen future değerlerine çevirdi.
# Out:
# array([[ 2.,  3.,  4.,  4.,  6.,  8.,  9., 12., 16.]])

# %%
trans.fit_transform(data)

# artık 3 tane değil 9 yeni feature'ım var.
# Out:
# array([[ 2.,  3.,  4.,  4.,  6.,  8.,  9., 12., 16.]])

# %% [markdown]
# ## Read Dataset

# %%
df = pd.read_csv("Advertising.csv")

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Polynomial Converter

# %%
X = df.drop("sales", axis =1)
y = df.sales

# %%
polynomial_converter = PolynomialFeatures(degree =2, include_bias =False)

# 2 dereden polynomial'e dönüştürdüm.

# %%
polynomial_converter
# Out:
# sklearn.preprocessing._data.PolynomialFeatures

# %%
polynomial_converter.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = polynomial_converter.transform(X)

# poly_features = polynomial_converter.fit_transform(X)    bu şekilde de tek adımda hem fit hem transform yapabiliyoruz.

# %%
poly_features
# Out:
# array([[ 230.1 ,   37.8 ,   69.2 , ..., 1428.84, 2615.76, 4788.64],
#        [  44.5 ,   39.3 ,   45.1 , ..., 1544.49, 1772.43, 2034.01],
#        [  17.2 ,   45.9 ,   69.3 , ..., 2106.81, 3180.87, 4802.49],
#        ...,
#        [ 177.  ,    9.3 ,    6.4 , ...,   86.49,   59.52,   40.96],
#        [ 283.6 ,   42.  ,   66.2 , ..., 1764.  , 2780.4 , 4382.44],
#        [ 232.1 ,    8.6 ,    8.7 , ...,   73.96,   74.82,   75.69]])

# %%
poly_features.shape
# Out:
# (200, 9)

# %%
pd.DataFrame(poly_features, columns = ["TV", "radio", "newspaper", "TV^2", "TV&Radio", \
                                   "TV&Newspaper", "Radio^2", "Radio&newspaper", "Newspaper^2"]).head()
# Out:
#       TV  radio  newspaper      TV^2  TV&Radio  TV&Newspaper  Radio^2  \
# 0  230.1   37.8       69.2  52946.01   8697.78      15922.92  1428.84
# 1   44.5   39.3       45.1   1980.25   1748.85       2006.95  1544.49
# 2   17.2   45.9       69.3    295.84    789.48       1191.96  2106.81
# 3  151.5   41.3       58.5  22952.25   6256.95       8862.75  1705.69
# 4  180.8   10.8       58.4  32688.64   1952.64      10558.72   116.64
#
#    Radio&newspaper  Newspaper^2
# 0          2615.76      4788.64
# 1          1772.43      2034.01
# 2          3180.87      4802.49
# 3          2416.05      3422.25
# 4           630.72      3410.56

# %%
X.shape
# Out:
# (200, 3)

# %% [raw]
# Müşteriye anlatmak niye sıkıntılı?
#
# Ben elde ettiğim yapay verilerden insight çıkarımı yaptım ama bunlar yapar veriler olduğu için bizi ve müşteriyi yanıltabilir.
#
# Gerçek hayat verilerine uygularken müşteri neden TV'nin karesini aldığımızı bile bilemez.
#
# Biz yeterli görmeyip yeni feature ları müşteriden talep ederiz.
# Ama amacımız sadece tahminimi iyileştirmek ise bu yöntem uygulanır.
# Gerçek verilerden yararlanmaktansa tahminimizi; yapay veri setlerini türetip iyileştirme yaptık. Sadece iyileştirme, gerçek hayata uyarlama değil.

# %% [markdown]
# ## Train | Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size = 0.3, random_state = 101)

# %% [markdown]
# ## Model for fitting

# %%
from sklearn.linear_model import LinearRegression

# %%
model_poly = LinearRegression()

# %%
model_poly.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_poly.predict(X_test)

# %%
my_dict = {"Actual": y_test, "pred": y_pred, "residual": y_test-y_pred}
compare = pd.DataFrame(my_dict)
compare.head(20)
# Out:
#      Actual       pred  residual
# 37     14.7  13.948562  0.751438
# 109    19.8  19.334803  0.465197
# 31     11.9  12.319282 -0.419282
# 89     16.7  16.762863 -0.062863
# 66      9.5   7.902109  1.597891
# 119     6.6   6.941438 -0.341438
# 54     20.2  20.133727  0.066273
# 74     17.0  17.500927 -0.500927
# 145    10.3  10.568890 -0.268890
# 142    20.1  20.125518 -0.025518
# 148    10.9   9.446145  1.453855
# 112    14.1  14.099354  0.000646
# 174    11.5  12.055135 -0.555135
# 55     23.7  23.392540  0.307460
# 141    19.2  19.675084 -0.475084
# 149    10.1   9.156263  0.943737
# 25     12.0  12.116373 -0.116373
# 34      9.5   9.281496  0.218504
# 170     8.4   8.446040 -0.046040
# 39     21.5  21.655881 -0.155881

# %%
compare.head(20).plot(kind='bar',figsize=(15,9))
plt.show();

# %% [raw]
# dereceyi arttırdıkça residual lar iyice azalacak ama bu durumda yeni sanal featurelarımız olacak ve bunu müşteriye anlatmak zor olacak.

# %% [markdown]
# ## Poly Coefficients

# %%
model_poly.coef_
# Out:
# array([ 5.17095811e-02,  1.30848864e-02,  1.20000085e-02, -1.10892474e-04,
#         1.14212673e-03, -5.24100082e-05,  3.34919737e-05,  1.46380310e-04,
#        -3.04715806e-05])

# %%
df_coef = pd.DataFrame(model_poly.coef_, index = ["TV", "radio", "newspaper", "TV^2", "TV&Radio", \
                                   "TV&Newspaper", "Radio^2", "Radio&newspaper", "Newspaper^2"], columns = ["coef"])

# %%
df_coef
# Out:
#                      coef
# TV               0.051710
# radio            0.013085
# newspaper        0.012000
# TV^2            -0.000111
# TV&Radio         0.001142
# TV&Newspaper    -0.000052
# Radio^2          0.000033
# Radio&newspaper  0.000146
# Newspaper^2     -0.000030

# %%
model_poly.predict([[2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
       8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
       4.788640e+03]])

# yukardaki coef katsayıları ile buradaki değerleri çarpıp bir de buna intercept değerini ekleyince yine aynı sonuca ulaşırsın. 
# Johnson hoca bunu ev ödevi olarak yapın dedi
# Out:
# array([21.86190699])

# %% [markdown]
# ## Evaluation on the Test Set

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred = model_poly.predict(X_test)

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance:")
    print("--------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
eval_metric(y_test, y_pred)
# Out:
# Model testing performance:
# --------------------------
# R2_score 	: 0.9843529333146795
# MAE 		: 0.48967980448035886
# MSE 		: 0.44175055104033895
# RMSE 		: 0.6646431757269

# %%
y_train_pred = model_poly.predict(X_train)

# %%
eval_metric(y_train, y_train_pred)
# Out:
# Model testing performance:
# --------------------------
# R2_score 	: 0.9868638137712757
# MAE 		: 0.4049248139151435
# MSE 		: 0.34569391424440005
# RMSE 		: 0.5879574085292234

# %% [markdown]
# * Simple Linear Regression:
#     * MAE      : 1.213
#     * RMSE     : 1.516
#     * r2_score : 0.8609
#
# * Polynomial 2-degree:
#     * MAE      : 0.48
#     * RMSE     : 0.66
#     * r2_score : 0.9868

# %% [markdown]
# ## Let's find optimal degree of poly

# %% [raw]
# Polinom linear reg. işte tamamen skorlarımızı iyileştirir.
#
# Ama feature sayımız artacak, hangi birini müşteriye anlatacağız ki. 1000 tane feature ımız olacak. Yani bunu insight etmek, müşteriye açıklamak anlamsız.
#
# Sadece predictimizin başarısını sentetik veriler ile arttırmaya yarıyor.
#
# Train ve test setimizin sonuçları arasındaki uçurum overfitting olduğunu gösterir.

# %%
# Poly Fonksiyonu: Yukarıdaki yaptığımız tüm işlemleri for döngüsü içerisinde yaptırdık

def poly(d):
    
    train_rmse_errors = []
    test_rmse_errors = []
    
    for i in range(1, d):
        polynomial_converter = PolynomialFeatures(degree = i, include_bias =False)
        poly_features = polynomial_converter.fit_transform(X)
        
        X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)
        
        model = LinearRegression(fit_intercept=True)
        model.fit(X_train, y_train)
        
        train_pred = model.predict(X_train)
        test_pred = model.predict(X_test)
        
        train_RMSE = np.sqrt(mean_squared_error(y_train,train_pred))
        test_RMSE = np.sqrt(mean_squared_error(y_test,test_pred))
        
        train_rmse_errors.append(train_RMSE)
        test_rmse_errors.append(test_RMSE)
        
    return pd.DataFrame({"train_rmse_errors": train_rmse_errors, "test_rmse_errors":test_rmse_errors}, index=[i for i in range(1,d)])

# %%
poly(10)

# derece 5 olduğunda patlamaya başladı. train error azalmaya devam ederken test errror birden 5 kat arttı. 
# daha sonra zaten iyice koptu.
# Out:
#    train_rmse_errors  test_rmse_errors
# 1           1.734594          1.516152
# 2           0.587957          0.664643
# 3           0.433934          0.580329
# 4           0.351708          0.507774
# 5           0.250934          2.575818
# 6           0.194063          4.305903
# 7           5.421706       1379.099015
# 8           0.143205       4212.996760
# 9           0.172515      95995.414928

# %%
# overfitting durumunu görselleştirerek görelim.

plt.plot(range(1,10), poly(10)["train_rmse_errors"], label = "TRAIN")
plt.plot(range(1,10), poly(10)["test_rmse_errors"], label = "TEST")
plt.xlabel("Polynamial Complex")
plt.ylabel("RMSE")
plt.legend();

# %%
 # arasındaki farkları görebilmek için burada 6. dereceye kadar aldım.

plt.plot(range(1,6), poly(6)["train_rmse_errors"], label = "TRAIN")
plt.plot(range(1,6), poly(6)["test_rmse_errors"], label = "TEST")
plt.xlabel("Polynamial Complex")
plt.ylabel("RMSE")
plt.legend();

# %% [raw]
# hangi dereceyi tercih edersin? 2 gibi gözüküyor ama hiç bir zaman sınırları tercih etme! 3 daha uygun
#
# 2'yi ve 3'ü seçmede sıkıntı yoktur. Ama patlama 4 te başladığı için 4 noktası seçilemez. Çünkü 4 noktası en sağlam en kuvvetli en önemli feature olsa bile bu nokta overfitting in başladığı noktadır.

# %% [markdown]
# ## Finalizing Model Choice

# %%
final_poly_converter = PolynomialFeatures(degree = 3)

# %%
final_model = LinearRegression()

# %%
final_model.fit(final_poly_converter.fit_transform(X), y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predictions

# %%
new_record = [[150, 20, 15]]

# %%
new_record_poly = final_poly_converter.fit_transform(new_record)

# %%
new_record_poly
# Out:
# array([[1.000e+00, 1.500e+02, 2.000e+01, 1.500e+01, 2.250e+04, 3.000e+03,
#         2.250e+03, 4.000e+02, 3.000e+02, 2.250e+02, 3.375e+06, 4.500e+05,
#         3.375e+05, 6.000e+04, 4.500e+04, 3.375e+04, 8.000e+03, 6.000e+03,
#         4.500e+03, 3.375e+03]])

# %%
final_model.predict(new_record_poly)
# Out:
# array([14.24950844])

# %% [markdown]
# ## Overfitting

# %%
over_poly_converter = PolynomialFeatures(degree =5)

# %%
over_model = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(over_poly_converter.fit_transform(X), y, test_size=0.3, random_state=101)

# %%
over_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_over = over_model.predict(X_test)

# %%
eval_metric(y_test, y_pred_over)
# Out:
# Model testing performance:
# --------------------------
# R2_score 	: 0.5764526500016582
# MAE 		: 0.7800982257750906
# MSE 		: 11.957658199857766
# RMSE 		: 3.457984702085561

# %%
y_train_over = over_model.predict(X_train)

# %%
eval_metric(y_train, y_train_over)
# Out:
# Model testing performance:
# --------------------------
# R2_score 	: 0.9969950598944347
# MAE 		: 0.22001404740143624
# MSE 		: 0.07907846989039792
# RMSE 		: 0.2812089434751283

# %% [raw]
# Benim modelim train setindeki skorları ezberlemiş. Ama hiç görmediği skorlarda bu değeri genelleyemediği için bu modelim overfitting oldu. Overfitting i engelleme yöntemlerimiz ve azaltma yntemlerimiz var.
